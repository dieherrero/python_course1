# %%
# PARSEADO DE LA PAGINA DE MINISTERIO DE SANIDAD Y CONSUMO, 
# antes solo conseguiamos los resultados de la primera pagina, analizando la pagina vemos que
# hay que añadir el parametro index

# %%
import requests
from bs4 import BeautifulSoup
import time

# Función adaptada del código anterior que buscaba solo en la primera página
def buscarDocsEnMSCBS(busqueda, sIndex=0):
    url = "https://www.mscbs.gob.es/buscador/iniciar.do"
    
    print("Buscando %s (%d)" %(busqueda, sIndex))

    parametros = {
        'search': busqueda,  
        'buscar': 'msc',    
        'sIndex': sIndex
    }

    respuesta = requests.post(url, parametros)

    html = respuesta.content.decode("utf-8")   
    soup = BeautifulSoup(html, 'html.parser')
    
    # Averiguamos el número total de resultados sacándolo de <div id="titulo_res">
    div = soup.find(id="titulo_res")
    
    if (div == None):
        return {"nResultados": 0, "articulos": []}  # No hemos encontrado nada
    
    nResultados = int(div.text.split(" ")[0])
    
    # Como en el ejemplo anterior obtenemos los títulos y URLs de los resultados
    
    cuadroResultados = soup.find('div', {"class": "capaCentroBuscador"})

    resultados = cuadroResultados.find_all('li')

    articulos = []
    
    for r in resultados:
        # Dentro de cada <li> tenemos un <p> con un <a href="URL_DE_LA_NOTICIA">
        urlNoticia = r.p.a['href']

        tituloNoticia = r.p.a.text

        articulos.append({'titulo': tituloNoticia, 'url': urlNoticia})
        
    return {"nResultados": nResultados, "articulos": articulos}

print("Introduzca lo que quiera buscar en el MSCBS:")
busqueda = input()
print("")

resultados = buscarDocsEnMSCBS(busqueda)

nResultados = resultados['nResultados']
articulos = resultados['articulos']

# Ahora tenemos que hacer búsquedas sucesivas para seguir obteniendo de 10 en 10
# el resto de artículos

for sIndex in range(10, nResultados, 10):
    time.sleep(0.5)      # Somo educados: no mandamos sucesivas peticiones sin dejar un poco
                    # de tiempo (1 segundo)
        
    resultados = buscarDocsEnMSCBS(busqueda, sIndex)
    
    articulos += resultados['articulos']
    

print("Se han encontrado %d artículos:" %(nResultados))
indice = 1

for a in articulos:
    print(str(indice) + " - " + a['titulo'])
    print("   " + a['url'])
    indice += 1
# Out:
# Introduzca lo que quiera buscar en el MSCBS:
# covid19
#
# Buscando covid19 (0)
# Buscando covid19 (10)
# Buscando covid19 (20)
# Buscando covid19 (30)
# Buscando covid19 (40)
# Buscando covid19 (50)
# Buscando covid19 (60)
# Buscando covid19 (70)
# Buscando covid19 (80)
# Buscando covid19 (90)
# Buscando covid19 (100)
# Buscando covid19 (110)
# Buscando covid19 (120)
# Buscando covid19 (130)
# Se han encontrado 136 artículos:
# 1 - [Ministerio de Sanidad, Consumo y Bienestar Social - Profesionales - Información para la ciudadanía - Coronavirus]
#    https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/ciudadania.htm
# 2 - [Ministerio de Sanidad, Consumo y Bienestar Social - Profesionales -
# Ruedas de prensa - COVID19]
#    https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/videosPrensa.htm
# 3 - [Ministerio de Sanidad, Consumo y Bienestar Social - Profesionales -
# Ruedas de prensa - COVID19]
#    https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/videosPrensa0420.htm
# 4 - [Ministerio de Sanidad, Consumo y Bienestar Social - Profesionales -
# Ruedas de prensa - COVID19
#  - Marzo]
#    https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/videosPrensa0320.htm
# 5 - [Ministerio de Sanidad, Consumo y Bienestar Social]
#    https://www.mscbs.gob.es/ssi/portada/home.htm
# 6 - [Ministerio de Sanidad, Consumo y Bienestar Social - Gabinete de Prensa - Notas de Prensa]
#    https://www.mscbs.gob.es/gabinete/notasPrensa.do?id=5005
# 7 - [Ministerio de Sanidad, Consumo y Bienestar Social - Ciudadanos - Cápsulas informativas Coronavirus y VIH]
#    https://www.mscbs.gob.es/ciudadanos/enfLesiones/enfTransmisibles/sida/homeCoronavirus.htm
# 8 - [Ministerio de Sanidad, Consumo y Bienestar Social - Gabinete de Prensa - Notas de Prensa]
#    https://www.mscbs.gob.es/gabinete/notasPrensa.do?id=5004
# 9 - [Medidas para mujeres que estén sufriendo violencia de género en situación de permanencia domiciliaria del estado de alarma por COVID-19 - Medidas sociales frente al coronavirus (COVID-19) - Ministerio de Derechos Sociales y Agenda 2030]
#    https://www.mscbs.gob.es/ssi/covid19/mujeres/home.htm
# 10 - [https://www.mscbs.gob.es/profesionales/saludPublica/prevPromocion/Estrategia/docs/ImplementacionLocal/Redes_comunitarias_en_la_crisis_de_COVID-19.pdf]
#    https://www.mscbs.gob.es/profesionales/saludPublica/prevPromocion/Estrategia/docs/ImplementacionLocal/Redes_comunitarias_en_la_crisis_de_COVID-19.pdf
# 11 - [Medidas urgentes en el ámbito social y económico para hacer frente al COVID-19 - Medidas sociales frente al coronavirus (COVID-19) - Ministerio de Derechos Sociales y Agenda 2030]
#    https://www.mscbs.gob.es/ssi/covid19/guia.htm
# 12 - [Ministerio de Sanidad, Consumo y Bienestar Social - Gabinete de Prensa - Notas de Prensa]
#    https://www.mscbs.gob.es/gabinete/notasPrensa.do?metodo=detalle&id=4976
# 13 - [Ministerio de Sanidad, Consumo y Bienestar Social - Gabinete de Prensa - Notas de Prensa]
#    https://www.mscbs.gob.es/gabinete/notasPrensa.do?metodo=detalle&id=4950
# 14 - [https://www.mscbs.gob.es/ssi/portada/docs/PREGUNTAS_FRECUENTES_SOBRE_LAS_MEDIDAS_SOCIALES_CONTRA_EL_CORONAVIRUS.pdf]
#    https://www.mscbs.gob.es/ssi/portada/docs/PREGUNTAS_FRECUENTES_SOBRE_LAS_MEDIDAS_SOCIALES_CONTRA_EL_CORONAVIRUS.pdf
# 15 - [Ministerio de Sanidad, Consumo y Bienestar Social - Gabinete de Prensa - Notas de Prensa]
#    https://www.mscbs.gob.es/gabinete/notasPrensa.do?metodo=detalle&id=4967
# 16 - [Ministerio de Sanidad, Consumo y Bienestar Social - Gabinete de Prensa - Notas de Prensa]
#    https://www.mscbs.gob.es/gabinete/notasPrensa.do?metodo=detalle&id=4954
# 17 - [https://www.mscbs.gob.es/gabinetePrensa/notaPrensa/pdf/GUIA110420172227802.pdf]
#    https://www.mscbs.gob.es/gabinetePrensa/notaPrensa/pdf/GUIA110420172227802.pdf
# 18 - [COVID19
#  y alcohol]
#    https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/documentos/COVID19_alcohol.pdf
# 19 - [Aplazamiento de las obligaciones de pago derivadas de subvenciones del Instituto para la diversificación y ahorro de la energía (IDAE) bajo la modalidad de préstamo - Medidas sociales frente al coronavirus (COVID-19) - Ministerio de Derechos Sociales]
#    https://www.mscbs.gob.es/ssi/covid19/energia/home.htm
# 20 - [Anexo III: Cronograma orientativo - Medidas sociales frente al coronavirus (COVID-19) - Ministerio de Derechos Sociales y Agenda 2030]
#    https://www.mscbs.gob.es/ssi/covid19/transicion/anexoIII.htm
# 21 - [Ministerio de Sanidad, Consumo y Bienestar Social - Consumo - Materiales de divulgación]
#    https://www.mscbs.gob.es/consumo/pec/divulgacion/home.htm
# 22 - [Presentación de PowerPoint]
#    https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/documentos/COVID19_Disfruta_del_agua.pdf
# 23 - [UNIVERSIDADES - Contratos, docentes, académicos, ayudantes, visitantes y personal general. - Medidas sociales frente al coronavirus (COVID-19) - Ministerio de Derechos Sociales y Agenda 2030]
#    https://www.mscbs.gob.es/ssi/covid19/universidades/home.htm
# 24 - [Ministerio de Sanidad, Consumo y Bienestar Social - Profesionales -
# Ruedas de prensa - COVID19]
#    https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/videosPrensa0520.htm
# 25 - [Apoyo a las PYMES. Aplazamiento extraordinario del calendario de reembolso en préstamos concedidos por la Secretaría General de Industria y de la Pequeña y Mediana Empresa - Medidas sociales frente al coronavirus (COVID-19) - Ministerio de Derechos S]
#    https://www.mscbs.gob.es/ssi/covid19/empresas/home.htm
# 26 - [https://www.mscbs.gob.es/gabinetePrensa/notaPrensa/pdf/04.06040620204922437.pdf]
#    https://www.mscbs.gob.es/gabinetePrensa/notaPrensa/pdf/04.06040620204922437.pdf
# 27 - [FONDO DE 300 M€ A LAS CCAA PARA APOYAR A LAS FAMÍLIAS EN TAREAS DE CUIDADOS - Medidas sociales frente al coronavirus (COVID-19) - Ministerio de Derechos Sociales y Agenda 2030]
#    https://www.mscbs.gob.es/ssi/covid19/ccaa/home.htm
# 28 - [Ciudadania_Cartel_LavadoManos (definitivo)]
#    https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/documentos/COVID19-Lavado_de_Manos.pdf
# 29 - [BECAS COMEDOR - Medidas sociales frente al coronavirus (COVID-19) - Ministerio de Derechos Sociales y Agenda 2030]
#    https://www.mscbs.gob.es/ssi/covid19/ninos/becas.htm
# 30 - [Suspensión de desahucios y de lanzamientos - Medidas sociales frente al coronavirus (COVID-19) - Ministerio de Derechos Sociales y Agenda 2030]
#    https://www.mscbs.gob.es/ssi/covid19/desahucios/home.htm
# 31 - [Contratación temporal de trabajadores en el sector agrario - Medidas sociales frente al coronavirus (COVID-19) - Ministerio de Derechos Sociales y Agenda 2030]
#    https://www.mscbs.gob.es/ssi/covid19/agrario/home.htm
# 32 - [Garantía del suministro de energía eléctrica, derivados del petróleo, gas y agua - Medidas sociales frente al coronavirus (COVID-19) - Ministerio de Derechos Sociales y Agenda 2030]
#    https://www.mscbs.gob.es/ssi/covid19/consumidores/home.htm
# 33 - [Prórroga contratos de arrendamiento - Medidas sociales frente al coronavirus (COVID-19) - Ministerio de Derechos Sociales y Agenda 2030]
#    https://www.mscbs.gob.es/ssi/covid19/desahucios/contratos.htm
# 34 - [Derechos de los animales - Medidas sociales frente al coronavirus (COVID-19) - Ministerio de Derechos Sociales y Agenda 2030]
#    https://www.mscbs.gob.es/ssi/covid19/animales/home.htm
# 35 - [https://www.mscbs.gob.es/ssi/covid19/documentos/Modelo-1.docx]
#    https://www.mscbs.gob.es/ssi/covid19/documentos/Modelo-1.docx
# 36 - [Aplazamiento de deudas tributarias - Medidas sociales frente al coronavirus (COVID-19) - Ministerio de Derechos Sociales y Agenda 2030]
#    https://www.mscbs.gob.es/ssi/covid19/autonomos/deudasTributarias.htm
# 37 - [UNIVERSIDADES - Contratos, docentes, académicos, ayudantes, visitantes y personal general. - Medidas sociales frente al coronavirus (COVID-19) - Ministerio de Derechos Sociales y Agenda 2030]
#    https://www.mscbs.gob.es/ssi/covid19/universidades/alumnos.htm
# 38 - [Interrupción del plazo de devolución de productos - Medidas sociales frente al coronavirus (COVID-19) - Ministerio de Derechos Sociales y Agenda 2030]
#    https://www.mscbs.gob.es/ssi/covid19/consumidores/devoluciones.htm
# 39 - [Subsidio extraordinario para empleadas del hogar - Medidas sociales frente al coronavirus (COVID-19) - Ministerio de Derechos Sociales y Agenda 2030]
#    https://www.mscbs.gob.es/ssi/covid19/trabajadores/home.htm
# 40 - [Prohibir los despidos - Medidas sociales frente al coronavirus (COVID-19) - Ministerio de Derechos Sociales y Agenda 2030]
#    https://www.mscbs.gob.es/ssi/covid19/mlaborales/despidos.htm
# 41 - [Ayudas para el pago del alquiler: aval bancario - Medidas sociales frente al coronavirus (COVID-19) - Ministerio de Derechos Sociales y Agenda 2030]
#    https://www.mscbs.gob.es/ssi/covid19/desahucios/aval.htm
# 42 - [https://www.mscbs.gob.es/ssi/covid19/documentos/Modelo-4.docx]
#    https://www.mscbs.gob.es/ssi/covid19/documentos/Modelo-4.docx
# 43 - [https://www.mscbs.gob.es/ssi/covid19/documentos/Modelo-4.pdf]
#    https://www.mscbs.gob.es/ssi/covid19/documentos/Modelo-4.pdf
# 44 - [Garantía de liquidez para sostener la actividad económica a autónomos y empresas - Medidas sociales frente al coronavirus (COVID-19) - Ministerio de Derechos Sociales y Agenda 2030]
#    https://www.mscbs.gob.es/ssi/covid19/autonomos/liquidez.htm
# 45 - [Prohibición del incremento de precios de servicios de comunicaciones durante la suspensión de la portabilidad - Medidas sociales frente al coronavirus (COVID-19) - Ministerio de Derechos Sociales y Agenda 2030]
#    https://www.mscbs.gob.es/ssi/covid19/consumidores/portabilidad.htm
# 46 - [Apoyo a empresas y autónomos del sector turístico - Medidas sociales frente al coronavirus (COVID-19) - Ministerio de Derechos Sociales y Agenda 2030]
#    https://www.mscbs.gob.es/ssi/covid19/autonomos/turismo.htm
# 47 - [Ministerio de Sanidad, Consumo y Bienestar Social - Notas prensa - COVID-19]
#    https://www.mscbs.gob.es/profesionales/cargarNotas.do?time=1590962400000
# 48 - [Ayudas para el pago del alquiler: préstamos del estado - Medidas sociales frente al coronavirus (COVID-19) - Ministerio de Derechos Sociales y Agenda 2030]
#    https://www.mscbs.gob.es/ssi/covid19/desahucios/prestamos.htm
# 49 - [Apoyo a las PYMES. Modificación en los plazos para aportar garantías en convocatorias de préstamos de la SGPYME - Medidas sociales frente al coronavirus (COVID-19) - Ministerio de Derechos Sociales y Agenda 2030]
#    https://www.mscbs.gob.es/ssi/covid19/empresas/plazos.htm
# 50 - [Percepción del bono social por trabajadores autónomos - Medidas sociales frente al coronavirus (COVID-19) - Ministerio de Derechos Sociales y Agenda 2030]
#    https://www.mscbs.gob.es/ssi/covid19/autonomos/home.htm
# 51 - [Moratoria de la deuda hipotecaria - Medidas sociales frente al coronavirus (COVID-19) - Ministerio de Derechos Sociales y Agenda 2030]
#    https://www.mscbs.gob.es/ssi/covid19/hipotecas/home.htm
# 52 - [Subsidio de desempleo excepcional por fin de contrato temporal - Medidas sociales frente al coronavirus (COVID-19) - Ministerio de Derechos Sociales y Agenda 2030]
#    https://www.mscbs.gob.es/ssi/covid19/trabajadores/subsidio.htm
# 53 - [Resolución de contratos de viaje combinado (viaje + alojamiento) - Medidas sociales frente al coronavirus (COVID-19) - Ministerio de Derechos Sociales y Agenda 2030]
#    https://www.mscbs.gob.es/ssi/covid19/consumidores/contratosViaje.htm
# 54 - [Prestación especial por desempleo al colectivo de artistas - Medidas sociales frente al coronavirus (COVID-19) - Ministerio de Derechos Sociales y Agenda 2030]
#    https://www.mscbs.gob.es/ssi/covid19/trabajadores/artistas.htm
# 55 - [Ayudas para estudiantes, investigadores y profesores - Medidas sociales frente al coronavirus (COVID-19) - Ministerio de Derechos Sociales y Agenda 2030]
#    https://www.mscbs.gob.es/ssi/covid19/universidades/ayudas.htm
# 56 - [https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/documentos/Recomendaciones_Actividades_tiempo_libre_infantil_y_juvenil.pdf]
#    https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/documentos/Recomendaciones_Actividades_tiempo_libre_infantil_y_juvenil.pdf
# 57 - [Defender a la gente trabajadora - Medidas sociales frente al coronavirus (COVID-19) - Ministerio de Derechos Sociales y Agenda 2030]
#    https://www.mscbs.gob.es/ssi/covid19/mlaborales/home.htm
# 58 - [Aplazamiento temporal en el pago de la renta - Medidas sociales frente al coronavirus (COVID-19) - Ministerio de Derechos Sociales y Agenda 2030]
#    https://www.mscbs.gob.es/ssi/covid19/desahucios/ayuda.htm
# 59 - [Apoyo a las PYMES. Refinanciación de los préstamos concedidos por la Secretaría General de Industria y Pequeña y Mediana Empresa - Medidas sociales frente al coronavirus (COVID-19) - Ministerio de Derechos Sociales y Agenda 2030]
#    https://www.mscbs.gob.es/ssi/covid19/empresas/prestamos.htm
# 60 - [Resolución de contratos sin penalización por los consumidores y usuarios - Medidas sociales frente al coronavirus (COVID-19) - Ministerio de Derechos Sociales y Agenda 2030]
#    https://www.mscbs.gob.es/ssi/covid19/consumidores/contratos.htm
# 61 - [Prestación extraordinaria por cese de actividad para autónomos - Medidas sociales frente al coronavirus (COVID-19) - Ministerio de Derechos Sociales y Agenda 2030]
#    https://www.mscbs.gob.es/ssi/covid19/autonomos/ceseActividad.htm
# 62 - [Moratoria renta para uso distinto del de vivienda con grandes tenedores - Medidas sociales frente al coronavirus (COVID-19) - Ministerio de Derechos Sociales y Agenda 2030]
#    https://www.mscbs.gob.es/ssi/covid19/desahucios/grandesTenedores.htm
# 63 - [SALIDA DE POBLACIÓN INFATIL - Medidas sociales frente al coronavirus (COVID-19) - Ministerio de Derechos Sociales y Agenda 2030]
#    https://www.mscbs.gob.es/ssi/covid19/ninos/home.htm
# 64 - [https://www.mscbs.gob.es/ssi/covid19/documentos/Modelo-5.docx]
#    https://www.mscbs.gob.es/ssi/covid19/documentos/Modelo-5.docx
# 65 - [https://www.mscbs.gob.es/ssi/covid19/documentos/Modelo-2.pdf]
#    https://www.mscbs.gob.es/ssi/covid19/documentos/Modelo-2.pdf
# 66 - [https://www.mscbs.gob.es/ssi/covid19/documentos/Modelo-3.docx]
#    https://www.mscbs.gob.es/ssi/covid19/documentos/Modelo-3.docx
# 67 - [https://www.mscbs.gob.es/ssi/covid19/documentos/Modelo-3.pdf]
#    https://www.mscbs.gob.es/ssi/covid19/documentos/Modelo-3.pdf
# 68 - [Moratoria de deuda del alquiler - Medidas sociales frente al coronavirus (COVID-19) - Ministerio de Derechos Sociales y Agenda 2030]
#    https://www.mscbs.gob.es/ssi/covid19/desahucios/moratoria.htm
# 69 - [Moratoria renta para uso distinto del de vivienda - Medidas sociales frente al coronavirus (COVID-19) - Ministerio de Derechos Sociales y Agenda 2030]
#    https://www.mscbs.gob.es/ssi/covid19/desahucios/usoDistinto.htm
# 70 - [Ministerio de Sanidad, Consumo y Bienestar Social - Gabinete de Prensa - Notas de Prensa]
#    https://www.mscbs.gob.es/gabinete/notasPrensa.do?metodo=detalle&id=4921
# 71 - [Autónomos. Moratoria de 6 meses para las cotizaciones a la Seguridad Social Social - Medidas sociales frente al coronavirus (COVID-19) - Ministerio de Derechos Sociales y Agenda 2030]
#    https://www.mscbs.gob.es/ssi/covid19/autonomos/deudasSS.htm
# 72 - [Anexo II: Previsión orientativa para el levantamiento de las limitaciones de ámbito nacional establecidas en el estado de alarma - Medidas sociales frente al coronavirus (COVID-19) - Ministerio de Derechos Sociales y Agenda 2030]
#    https://www.mscbs.gob.es/ssi/covid19/transicion/home.htm
# 73 - [Apoyo a las PYMES. Flexibilización en los contratos de suministro de electricidad para autónomos y empresas - Medidas sociales frente al coronavirus (COVID-19) - Ministerio de Derechos Sociales y Agenda 2030]
#    https://www.mscbs.gob.es/ssi/covid19/empresas/suministros.htm
# 74 - [Ampliación protección desempleo - Medidas sociales frente al coronavirus (COVID-19) - Ministerio de Derechos Sociales y Agenda 2030]
#    https://www.mscbs.gob.es/ssi/covid19/mlaborales/ampliacion.htm
# 75 - [Suspensión de las obligaciones derivadas de los contratos de crédito sin garantía hipotecaria - Medidas sociales frente al coronavirus (COVID-19) - Ministerio de Derechos Sociales y Agenda 2030]
#    https://www.mscbs.gob.es/ssi/covid19/consumidores/suspensionObligaciones.htm
# 76 - [Documento técnico]
#    https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/documentos/Documento_manejo_embarazo_recien_nacido.pdf
# 77 - [https://www.mscbs.gob.es/gabinetePrensa/notaPrensa/pdf/Compa040620141224392.pdf]
#    https://www.mscbs.gob.es/gabinetePrensa/notaPrensa/pdf/Compa040620141224392.pdf
# 78 - [CRONICOS_20200403]
#    https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/documentos/CRONICOS20200403.pdf
# 79 - [Aspectos claves para la prevención del VIH e ITS en la desescalada del confinamiento por COVID-19]
#    https://www.mscbs.gob.es/ciudadanos/enfLesiones/enfTransmisibles/sida/docs/Plan_Transicion_ITS1.pdf
# 80 - [https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/documentos/Coronavirus_y_Agua_de_Consumo.pdf]
#    https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/documentos/Coronavirus_y_Agua_de_Consumo.pdf
# 81 - [Infovhital_COVID]
#    https://www.mscbs.gob.es/ciudadanos/enfLesiones/enfTransmisibles/sida/docs/Infovhital_COVID_2020.pdf
# 82 - [https://www.mscbs.gob.es/biblioPublic/publicaciones/recursos_propios/resp/revista_cdrom/VOL94/ORIGINALES/RS94C_202007084.pdf]
#    https://www.mscbs.gob.es/biblioPublic/publicaciones/recursos_propios/resp/revista_cdrom/VOL94/ORIGINALES/RS94C_202007084.pdf
# 83 - [https://www.mscbs.gob.es/ciudadanos/ene-covid/docs/ESTUDIO_ENE-COVID19_PRIMERA_RONDA_INFORME_PRELIMINAR.pdf]
#    https://www.mscbs.gob.es/ciudadanos/ene-covid/docs/ESTUDIO_ENE-COVID19_PRIMERA_RONDA_INFORME_PRELIMINAR.pdf
# 84 - [Presentación de PowerPoint]
#    https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/documentos/COVID19-hemodialisis-resumen-visual.pdf
# 85 - [https://www.mscbs.gob.es/gabinetePrensa/notaPrensa/pdf/Compa280520124120682.pdf]
#    https://www.mscbs.gob.es/gabinetePrensa/notaPrensa/pdf/Compa280520124120682.pdf
# 86 - [Ministerio de Sanidad, Consumo y Bienestar Social - Gabinete de Prensa - Notas de Prensa]
#    https://www.mscbs.gob.es/gabinete/notasPrensa.do?metodo=detalle&id=4829
# 87 - [Ministerio de Sanidad, Consumo y Bienestar Social - Gabinete de Prensa - Notas de Prensa]
#    https://www.mscbs.gob.es/gabinete/notasPrensa.do?metodo=detalle&id=4914
# 88 - [Ministerio de Sanidad, Consumo y Bienestar Social - Gabinete de Prensa - Notas de Prensa]
#    https://www.mscbs.gob.es/gabinete/notasPrensa.do?time=1590962400000
# 89 - [Ministerio de Sanidad, Consumo y Bienestar Social - Ciudadanos - Preguntas y respuestas frecuentes - Estudio Nacional Epidemiológico de la infección por COVID-19 en España (ENE-COVID)]
#    https://www.mscbs.gob.es/ciudadanos/ene-covid/faqs.htm
# 90 - [Ministerio de Sanidad, Consumo y Bienestar Social - Gabinete de Prensa - Notas de Prensa]
#    https://www.mscbs.gob.es/gabinete/notasPrensa.do?metodo=detalle&id=4864
# 91 - [Ministerio de Sanidad, Consumo y Bienestar Social - Gabinete de Prensa - Notas de Prensa]
#    https://www.mscbs.gob.es/gabinete/notasPrensa.do?metodo=detalle&id=4874
# 92 - [https://www.mscbs.gob.es/biblioPublic/publicaciones/recursos_propios/resp/revista_cdrom/VOL94/C_ESPECIALES/RS94C_202006061.pdf]
#    https://www.mscbs.gob.es/biblioPublic/publicaciones/recursos_propios/resp/revista_cdrom/VOL94/C_ESPECIALES/RS94C_202006061.pdf
# 93 - [Ministerio de Sanidad, Consumo y Bienestar Social - Gabinete de Prensa - Notas de Prensa]
#    https://www.mscbs.gob.es/gabinete/notasPrensa.do?metodo=detalle&id=4882
# 94 - [https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/documentos/Manejo_cadaveres_COVID-19.pdf]
#    https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/documentos/Manejo_cadaveres_COVID-19.pdf
# 95 - [https://www.mscbs.gob.es/gabinetePrensa/notaPrensa/pdf/Compa210520125641574.pdf]
#    https://www.mscbs.gob.es/gabinetePrensa/notaPrensa/pdf/Compa210520125641574.pdf
# 96 - [RS94C_202006065.indd]
#    https://www.mscbs.gob.es/biblioPublic/publicaciones/recursos_propios/resp/revista_cdrom/VOL94/ORIGINALES/RS94C_202006065.pdf
# 97 - [https://www.mscbs.gob.es/gabinetePrensa/notaPrensa/pdf/COMPA240620161804652.pdf]
#    https://www.mscbs.gob.es/gabinetePrensa/notaPrensa/pdf/COMPA240620161804652.pdf
# 98 - [https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/documentos/Recomendaciones_mascarillas_ambito_comunitario.pdf]
#    https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/documentos/Recomendaciones_mascarillas_ambito_comunitario.pdf
# 99 - [Ministerio de Sanidad, Consumo y Bienestar Social - Profesionales - Agua
# y COVID19]
#    https://www.mscbs.gob.es/profesionales/saludPublica/saludAmbLaboral/calidadAguas/AGUAYCOVID19/home.htm
# 100 - [https://www.mscbs.gob.es/gabinetePrensa/notaPrensa/pdf/08.04080520142537303.pdf]
#    https://www.mscbs.gob.es/gabinetePrensa/notaPrensa/pdf/08.04080520142537303.pdf
# 101 - [https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/documentos/Recomendaciones_VOLUNTARIADO.pdf]
#    https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/documentos/Recomendaciones_VOLUNTARIADO.pdf
# 102 - [https://www.mscbs.gob.es/gabinetePrensa/notaPrensa/pdf/23.06230620172718716.pdf]
#    https://www.mscbs.gob.es/gabinetePrensa/notaPrensa/pdf/23.06230620172718716.pdf
# 103 - [https://www.mscbs.gob.es/ssi/familiasInfancia/ServiciosSociales/docs/Covid19/Rec_personas_sin_hogar.pdf]
#    https://www.mscbs.gob.es/ssi/familiasInfancia/ServiciosSociales/docs/Covid19/Rec_personas_sin_hogar.pdf
# 104 - [https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/documentos/COVID19-hemodialisis.pdf]
#    https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/documentos/COVID19-hemodialisis.pdf
# 105 - [Doc preg mayo_COVID_UNIDAD TÉCNICA CIE_27052020]
#    https://www.mscbs.gob.es/estadEstudios/estadisticas/normalizacion/CIE10/3_Documento_Preguntas_COVID19_27_05_2020.pdf
# 106 - [https://www.mscbs.gob.es/estadEstudios/estadisticas/normalizacion/CIE10/Norm_COVID19_Primer_Semestre_2020.pdf]
#    https://www.mscbs.gob.es/estadEstudios/estadisticas/normalizacion/CIE10/Norm_COVID19_Primer_Semestre_2020.pdf
# 107 - [https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/documentos/ITCoronavirus.pdf]
#    https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/documentos/ITCoronavirus.pdf
# 108 - [https://www.mscbs.gob.es/gabinetePrensa/notaPrensa/pdf/26.03260320134953882.pdf]
#    https://www.mscbs.gob.es/gabinetePrensa/notaPrensa/pdf/26.03260320134953882.pdf
# 109 - [https://www.mscbs.gob.es/gabinetePrensa/notaPrensa/pdf/13.05130520204528614.pdf]
#    https://www.mscbs.gob.es/gabinetePrensa/notaPrensa/pdf/13.05130520204528614.pdf
# 110 - [Directrices_PlasmaConv_CCST_25 de Junio 2020]
#    https://www.mscbs.gob.es/profesionales/saludPublica/medicinaTransfusional/acuerdos/docs/COVID-19_RecPlasma_donantes.pdf
# 111 - [https://www.mscbs.gob.es/estadEstudios/estadisticas/estadisticas/estMinisterio/SIAP/Extensiones_CIAP-2.xlsx]
#    https://www.mscbs.gob.es/estadEstudios/estadisticas/estadisticas/estMinisterio/SIAP/Extensiones_CIAP-2.xlsx
# 112 - [https://www.mscbs.gob.es/gabinetePrensa/notaPrensa/pdf/16.04080520143349074.pdf]
#    https://www.mscbs.gob.es/gabinetePrensa/notaPrensa/pdf/16.04080520143349074.pdf
# 113 - [https://www.mscbs.gob.es/gabinetePrensa/notaPrensa/pdf/02.04080520142141228.pdf]
#    https://www.mscbs.gob.es/gabinetePrensa/notaPrensa/pdf/02.04080520142141228.pdf
# 114 - [https://www.mscbs.gob.es/gabinetePrensa/notaPrensa/pdf/23.04080520143642800.pdf]
#    https://www.mscbs.gob.es/gabinetePrensa/notaPrensa/pdf/23.04080520143642800.pdf
# 115 - [NOTA INTERIOR]
#    https://www.mscbs.gob.es/ssi/familiasInfancia/ServiciosSociales/docs/Covid19/Rec_ssss_desescalada.pdf
# 116 - [Informe datos globales 2.0]
#    https://www.mscbs.gob.es/profesionales/saludPublica/prevPromocion/promocion/desigualdadSalud/docs/COVID-19_Impacto_PoblacionGitana.pdf
# 117 - [Aspectos claves para la prevención del VIH e ITS en la desescalada del confinamiento por COVID-19]
#    https://www.mscbs.gob.es/ciudadanos/enfLesiones/enfTransmisibles/sida/docs/Plan_Transicion_ITS.pdf
# 118 - [Ministerio de Sanidad, Consumo y Bienestar Social - Profesionales - Salud Pública - Prevención y Promoción - Plan Tuberculosis]
#    https://www.mscbs.gob.es/profesionales/saludPublica/prevPromocion/PlanTuberculosis/planTuberculosis.htm
# 119 - [Ministerio de Sanidad, Consumo y Bienestar Social - Ciudadanos - Distancia física segura durante la práctica de deporte al aire libre]
#    https://www.mscbs.gob.es/biblioPublic/publicaciones/recursos_propios/resp/revista_cdrom/Suplementos/Pildoras/pildora23.htm
# 120 - [https://www.mscbs.gob.es/biblioPublic/publicaciones/recursos_propios/resp/revista_cdrom/VOL94/CARTA/RS94C_202007086.pdf]
#    https://www.mscbs.gob.es/biblioPublic/publicaciones/recursos_propios/resp/revista_cdrom/VOL94/CARTA/RS94C_202007086.pdf
# 121 - [Ministerio de Sanidad, Consumo y Bienestar Social - Ciudadanos - Transmisión entre personas que trabajan en hospitales (sanitarios y no) en Madrid]
#    https://www.mscbs.gob.es/biblioPublic/publicaciones/recursos_propios/resp/revista_cdrom/Suplementos/Pildoras/pildora18.htm
# 122 - [https://www.mscbs.gob.es/gabinetePrensa/notaPrensa/pdf/Compa140520131410803.pdf]
#    https://www.mscbs.gob.es/gabinetePrensa/notaPrensa/pdf/Compa140520131410803.pdf
# 123 - [perspectivas6_delaguilaetal.indd]
#    https://www.mscbs.gob.es/biblioPublic/publicaciones/recursos_propios/resp/revista_cdrom/Suplementos/Perspectivas/perspectivas6_delaguilaetal.pdf
# 124 - [https://www.mscbs.gob.es/gabinetePrensa/notaPrensa/pdf/COMPA070520131205847.pdf]
#    https://www.mscbs.gob.es/gabinetePrensa/notaPrensa/pdf/COMPA070520131205847.pdf
# 125 - [https://www.mscbs.gob.es/biblioPublic/publicaciones/recursos_propios/resp/revista_cdrom/Suplementos/Perspectivas/perspectivas2_gallego.pdf]
#    https://www.mscbs.gob.es/biblioPublic/publicaciones/recursos_propios/resp/revista_cdrom/Suplementos/Perspectivas/perspectivas2_gallego.pdf
# 126 - [https://www.mscbs.gob.es/profesionales/saludPublica/prevPromocion/PlanTuberculosis/docs/Covid19-TB_es.pdf]
#    https://www.mscbs.gob.es/profesionales/saludPublica/prevPromocion/PlanTuberculosis/docs/Covid19-TB_es.pdf
# 127 - [https://www.mscbs.gob.es/biblioPublic/publicaciones/recursos_propios/resp/revista_cdrom/VOL94/REVISIONES/RS94C_202005055.pdf]
#    https://www.mscbs.gob.es/biblioPublic/publicaciones/recursos_propios/resp/revista_cdrom/VOL94/REVISIONES/RS94C_202005055.pdf
# 128 - [https://www.mscbs.gob.es/biblioPublic/publicaciones/recursos_propios/resp/revista_cdrom/Suplementos/Pildoras/pildora23_distancia_fisica_practica_deporte_aire_libre.pdf]
#    https://www.mscbs.gob.es/biblioPublic/publicaciones/recursos_propios/resp/revista_cdrom/Suplementos/Pildoras/pildora23_distancia_fisica_practica_deporte_aire_libre.pdf
# 129 - [https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/documentos/20200602_ITCoronavirus.pdf]
#    https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/documentos/20200602_ITCoronavirus.pdf
# 130 - [https://www.mscbs.gob.es/biblioPublic/publicaciones/recursos_propios/resp/revista_cdrom/Suplementos/Pildoras/pildora18_transmision_entre_personas_que_trabajan_en_hospitales_en_madrid.pdf]
#    https://www.mscbs.gob.es/biblioPublic/publicaciones/recursos_propios/resp/revista_cdrom/Suplementos/Pildoras/pildora18_transmision_entre_personas_que_trabajan_en_hospitales_en_madrid.pdf
# 131 - [RS94C_202006054.indd]
#    https://www.mscbs.gob.es/biblioPublic/publicaciones/recursos_propios/resp/revista_cdrom/VOL94/C_ESPECIALES/RS94C_202006054.pdf
# 132 - [https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/documentos/20200518_ITCoronavirus.pdf]
#    https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/documentos/20200518_ITCoronavirus.pdf
# 133 - [https://www.mscbs.gob.es/biblioPublic/publicaciones/recursos_propios/resp/revista_cdrom/VOL94/REVISIONES/RS94C_202007088.pdf]
#    https://www.mscbs.gob.es/biblioPublic/publicaciones/recursos_propios/resp/revista_cdrom/VOL94/REVISIONES/RS94C_202007088.pdf
# 134 - [Microsoft Word - HOJA RESUMEN (2).docx]
#    https://www.mscbs.gob.es/ciudadanos/enfLesiones/enfTransmisibles/sida/EPICOS/RESUMEN.pdf
# 135 - [PLAN DE RESPUESTA TEMPRANA ESCENARIO CONTROL COVID-19_FINAL_13julio]
#    https://www.mscbs.gob.es/gabinetePrensa/notaPrensa/pdf/13.07130720131534059.pdf
# 136 - [https://www.mscbs.gob.es/gabinetePrensa/notaPrensa/pdf/21.07210720123340826.pdf]
#    https://www.mscbs.gob.es/gabinetePrensa/notaPrensa/pdf/21.07210720123340826.pdf

# %%
# ROBOTS RECURSIVOS

# %%
from urllib.parse import urlparse    # Utilizadas para parsear más fácilmente las URLs que encontremos.
from urllib.parse import urlunparse  #
from urllib.parse import urljoin     #

import requests
from bs4 import BeautifulSoup
import time
import shutil                        # Una utilidad que permite copiar ficheros facilmente
import os
import errno


retardoEntrePeticiones = 0.5

# A esta función se le pasa una URL padre "completa" (con esquema y netloc: 
# http://example.com...)
# y una "hija" que probablemente se habrá sacado de un <a href="">. La hija probablemente
# no tenga ni esquema ni netloc. Esta función se asegura de devolver la hija pero
# con el esquema y el netloc correspondientes. Si la hija ya tiene netloc la devolverá tal cual.
# Ejemplos:
#  Padre: "https://etsiit.ugr.es/pages/calendario_academico" 
#  Hija: "horariosnuevocurso"
#  Devuelve: "https://etsiit.ugr.es/pages/calendario_academico/horariosnuevocurso"
#
#  Padre: "https://etsiit.ugr.es/pages/escuela"
#  Hija: "/pages/docencia"
#  Devuelve: https://etsiit.ugr.es/pages/docencia
#  
#  Padre: "https://etsiit.ugr.es/pages/escuela"
#  Hija: "https://www.ugr.es"
#  Devuelve: "https://www.ugr.es"
# 
# Ojo, no está probada con parámetros y similares 

def getURLCompleta(padreURL, hijaURL):
    hija = urlparse(hijaURL)
    padre = urlparse(padreURL)
    
    netloc = hija.netloc
    scheme = hija.scheme
    path = hija.path
    
    if (netloc == ''):   # Si no tiene netloc, se lo añadimos
        netloc = padre.netloc
        scheme = padre.scheme
        
        path = urljoin(padre.path, hija.path)
    
    return urlunparse((scheme, netloc, path, hija.params, hija.query, hija.fragment))
    
# Devuelve True si las dos urls son del mismo servidor
def sonDelMismoServidor(url1, url2):
    url1p = urlparse(url1)
    url2p = urlparse(url2)
    
    server1 = url1p.netloc.split(".")[-2:]
    server2 = url2p.netloc.split(".")[-2:]
    
    if server1[0]==server2[0] and server1[1]==server2[1]:
        return True
    
    return False

# Crea todos los directorios necesarios en el path de un fichero
def crearDirectoriosDeUnPath(path):
    if not os.path.exists(os.path.dirname(path)):
        try:
            os.makedirs(os.path.dirname(path))
        except OSError as exc: # Guard against race condition
            if exc.errno != errno.EEXIST:
                raise

    
    

def descargaImagen(url, directorio):
    urlp = urlparse(url)
    
    nombreFichero = directorio + urlp.netloc + urlp.path
    #print(nombreFichero)
    
    if not os.path.exists(nombreFichero):  # Si ya existe es que lo descargamos en una ejecución anterior
        time.sleep(retardoEntrePeticiones)   # Dejamos un tiempo por educación

        crearDirectoriosDeUnPath(nombreFichero)

        print("Descargando imagen %s" % (url))

        resp = requests.get(url, stream=True)

        local_file = open(nombreFichero, 'wb')
    # Set decode_content value to True, otherwise the downloaded image file's size will be zero.
        resp.raw.decode_content = True
    # Copy the response stream raw data to local image file.
        shutil.copyfileobj(resp.raw, local_file)
    # Remove the image url response object.
        del resp
        
        return True
    
    return False

# Preguntamos la web a escrapear y otros parámetros
print("Inserte la URL a scrapear:")
url = input("Por ejemplo: https://wallpaperscraft.com/ ")
if url == '': url = "https://wallpaperscraft.com/"
    
print("\nMáximo nivel de profundidad en la búsqueda:")
profundidadMaxima = input("Por ejemplo: 1 ")
if profundidadMaxima == '': 
    profundidadMaxima = 1 
else: 
    profundidadMaxima = int(profundidadMaxima)

print("\nDirectorio donde guardar las imágenes:")
directorioImagenes = input("Por ejemplo: /home/zerjillo/temp/imagenes/ ")
if directorioImagenes == '':
    directorioImagenes =  "/home/diego/"


# Creamos arrays para las URLs que todavía tenemos que parsear y las que ya hemos visitado
# Las visitadas las apuntamos para evitar descargar dos veces la misma URL.
urlsPendientes = [{'url' : url, 'profundidad' : 1}]
urlsVisitadas = []  
imagenesDescargadas = 0

# Mientras que queden URLs por parsear
while(len(urlsPendientes) > 0):
    x = urlsPendientes.pop()
    
    urlActual = x['url']
    profundidadActual = x['profundidad']
    
    urlsVisitadas.append(urlActual)  # Para no visitar de nuevo esta misma URL
    
    time.sleep(retardoEntrePeticiones)    # Dejamos un tiempo por educación
    
    print("Descargando página %s" % (urlActual))
    
    respuesta = requests.get(urlActual)

    try:
        html = respuesta.content.decode("utf-8")   
        soup = BeautifulSoup(html, 'html.parser')


    # Si no hemos llegado al nivel de profundidad maximo, buscamos todos los enlaces y los mete
        if profundidadActual < profundidadMaxima:
            enlaces = soup.findAll('a')

            for enlace in enlaces:
                urlEnlace = enlace['href']

                if urlEnlace != '':
                    urlEnlace = getURLCompleta(urlActual, urlEnlace)

                    if sonDelMismoServidor(urlActual, urlEnlace) and not urlEnlace in urlsVisitadas and not urlEnlace in urlsPendientes:
                        #print(urlEnlace)
                        urlsPendientes.append({'url': urlEnlace, 'profundidad': profundidadActual + 1})


    # Descargamos las imágenes
        imagenes = soup.findAll('img')


        for imagen in imagenes:
            urlImagen = imagen['src']

            if urlImagen != '':
                urlImagen = getURLCompleta(urlActual, urlImagen)

                if not urlImagen in urlsVisitadas:
                    if descargaImagen(urlImagen, directorioImagenes):
                        print("Quedan %d páginas, imagenes descargadas %d" % (len(urlsPendientes), imagenesDescargadas))

                        imagenesDescargadas += 1
                        
                    urlsVisitadas.append(urlImagen)
                    
           
        del respuesta
    except Exception as e: 
        print(e)
        print("Problema parsean página ¿binario?")
# Out:
# Inserte la URL a scrapear:
# Por ejemplo: https://wallpaperscraft.com/
#
# Máximo nivel de profundidad en la búsqueda:
# Por ejemplo: 1
#
# Directorio donde guardar las imágenes:
# Por ejemplo: /home/zerjillo/temp/imagenes/
# Descargando página https://wallpaperscraft.com/
# name 'urlparse' is not defined
# Problema parsean página ¿binario?
